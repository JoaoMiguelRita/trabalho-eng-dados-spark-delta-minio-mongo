# %% [markdown]
# # 01 - Extração: SQL Server → MinIO (CSV)
#
# Extrai **todas as tabelas** do database `SeguroDB` do SQL Server e exporta como CSV para o bucket `landing-zone` no MinIO.
#
# **Pré-requisitos:** Docker Compose rodando, Notebook `00` executado.

# %% [markdown]
# ## 1. Configuração

# %%
import os, io
import pandas as pd
import pyodbc
import boto3
from botocore.client import Config
from dotenv import load_dotenv

load_dotenv(override=True)

DB_SERVER   = os.getenv('DB_SERVER')
DB_PORT     = os.getenv('DB_PORT')
DB_USER     = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_DATABASE = os.getenv('DB_DATABASE')

MINIO_ENDPOINT   = os.getenv('MINIO_ENDPOINT')
MINIO_ACCESS_KEY = os.getenv('MINIO_ACCESS_KEY')
MINIO_SECRET_KEY = os.getenv('MINIO_SECRET_KEY')
LANDING_BUCKET   = os.getenv('MINIO_LANDING_BUCKET')

print(f'SQL Server: {DB_SERVER}:{DB_PORT}/{DB_DATABASE}')
print(f'MinIO: {MINIO_ENDPOINT} | Bucket: {LANDING_BUCKET}')
# Out:
# SQL Server: localhost:1433/SeguroDB
# MinIO: http://localhost:9020 | Bucket: landing-zone

# %% [markdown]
# ## 2. Conexão com SQL Server

# %%
conn = pyodbc.connect(
    f'DRIVER={{ODBC Driver 18 for SQL Server}};'
    f'SERVER={DB_SERVER},{DB_PORT};'
    f'DATABASE={DB_DATABASE};'
    f'UID={DB_USER};PWD={DB_PASSWORD};'
    f'TrustServerCertificate=yes;'
)
cursor = conn.cursor()
print(f'Conectado ao SQL Server [{DB_DATABASE}]')
# Out:
# Conectado ao SQL Server [SeguroDB]

# %% [markdown]
# ## 3. Listar Tabelas

# %%
cursor.execute("""
    SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES
    WHERE TABLE_TYPE = 'BASE TABLE' AND TABLE_SCHEMA = 'dbo'
    ORDER BY TABLE_NAME
""")
tabelas = [row[0] for row in cursor.fetchall()]

print(f'{len(tabelas)} tabelas encontradas:')
for i, t in enumerate(tabelas, 1):
    cursor.execute(f'SELECT COUNT(*) FROM [{t}]')
    print(f'  {i:2d}. {t:<20} ({cursor.fetchone()[0]:>6} registros)')
# Out:
# 11 tabelas encontradas:
#    1. apolice              ( 10000 registros)
#    2. carro                ( 10002 registros)
#    3. cliente              ( 20010 registros)
#    4. endereco             ( 20010 registros)
#    5. estado               (    27 registros)
#    6. marca                (    10 registros)
#    7. modelo               (   100 registros)
#    8. municipio            (  5570 registros)
#    9. regiao               (     5 registros)
#   10. sinistro             ( 10000 registros)
#   11. telefone             ( 20010 registros)

# %% [markdown]
# ## 4. Criar Bucket no MinIO

# %%
s3_client = boto3.client(
    's3',
    endpoint_url=MINIO_ENDPOINT,
    aws_access_key_id=MINIO_ACCESS_KEY,
    aws_secret_access_key=MINIO_SECRET_KEY,
    config=Config(signature_version='s3v4'),
    region_name='us-east-1'
)

try:
    s3_client.head_bucket(Bucket=LANDING_BUCKET)
    print(f'Bucket [{LANDING_BUCKET}] já existe')
except:
    s3_client.create_bucket(Bucket=LANDING_BUCKET)
    print(f'Bucket [{LANDING_BUCKET}] criado!')

print('Buckets:', [b['Name'] for b in s3_client.list_buckets()['Buckets']])
# Out:
# Bucket [landing-zone] criado!
# Buckets: ['landing-zone']

# %% [markdown]
# ## 5. Extrair Tabelas → CSV no MinIO

# %%
print(f'Extraindo {len(tabelas)} tabelas...\n')
resultados = []

for tabela in tabelas:
    # Ler tabela via cursor (evita warning do pd.read_sql com pyodbc)
    cursor.execute(f'SELECT * FROM [{tabela}]')
    columns = [desc[0] for desc in cursor.description]
    rows = cursor.fetchall()
    df = pd.DataFrame.from_records(rows, columns=columns)

    csv_buffer = io.StringIO()
    df.to_csv(csv_buffer, index=False)
    csv_bytes = csv_buffer.getvalue().encode('utf-8')
    s3_key = f'{tabela}.csv'

    s3_client.put_object(
        Bucket=LANDING_BUCKET, Key=s3_key,
        Body=csv_bytes, ContentType='text/csv'
    )

    size_kb = len(csv_bytes) / 1024
    resultados.append({'tabela': tabela, 'registros': len(df), 'colunas': len(df.columns), 'tamanho_kb': round(size_kb,1)})
    print(f'  {tabela}.csv -> s3://{LANDING_BUCKET}/{s3_key} ({len(df)} registros, {size_kb:.1f} KB)')

print(f'\nExtracao concluida! {len(tabelas)} tabelas exportadas.')
# Out:
# Extraindo 11 tabelas...
#
#   apolice.csv -> s3://landing-zone/apolice.csv (10000 registros, 755.2 KB)
#   carro.csv -> s3://landing-zone/carro.csv (10002 registros, 340.1 KB)
#   cliente.csv -> s3://landing-zone/cliente.csv (20010 registros, 922.6 KB)
#   endereco.csv -> s3://landing-zone/endereco.csv (20010 registros, 1012.9 KB)
#   estado.csv -> s3://landing-zone/estado.csv (27 registros, 0.5 KB)
#   marca.csv -> s3://landing-zone/marca.csv (10 registros, 0.1 KB)
#   modelo.csv -> s3://landing-zone/modelo.csv (100 registros, 1.2 KB)
#   municipio.csv -> s3://landing-zone/municipio.csv (5570 registros, 131.2 KB)
#   regiao.csv -> s3://landing-zone/regiao.csv (5 registros, 0.1 KB)
#   sinistro.csv -> s3://landing-zone/sinistro.csv (10000 registros, 378.0 KB)
#   telefone.csv -> s3://landing-zone/telefone.csv (20010 registros, 319.2 KB)
#
# Extracao concluida! 11 tabelas exportadas.

# %% [markdown]
# ## 6. Validação

# %%
response = s3_client.list_objects_v2(Bucket=LANDING_BUCKET)
print(f'Arquivos no bucket [{LANDING_BUCKET}]:\n')
for obj in response.get('Contents', []):
    print(f'  {obj["Key"]:<25} {obj["Size"]/1024:>8.1f} KB')

df_resumo = pd.DataFrame(resultados)
print(f'\nTotal: {df_resumo["registros"].sum():,} registros | {df_resumo["tamanho_kb"].sum():,.1f} KB')
# Out:
# Arquivos no bucket [landing-zone]:
#
#   apolice.csv                  755.2 KB
#   carro.csv                    340.1 KB
#   cliente.csv                  922.6 KB
#   endereco.csv                1012.9 KB
#   estado.csv                     0.5 KB
#   marca.csv                      0.1 KB
#   modelo.csv                     1.2 KB
#   municipio.csv                131.2 KB
#   regiao.csv                     0.1 KB
#   sinistro.csv                 378.0 KB
#   telefone.csv                 319.2 KB
#
# Total: 95,744 registros | 3,861.1 KB

# %%
cursor.close()
conn.close()
print('Conexao SQL Server encerrada.')
# Out:
# Conexao SQL Server encerrada.
